# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Set the seaborn 
sns.set_theme()

# %%
covid = pd.read_csv("data/covid_19_clean_complete.csv",
                       parse_dates=True)
world = pd.read_csv("data/worldometer_data.csv")

# %%
covid.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
covid.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
covid.rename(columns = {"Province/State": "State", "Country/Region": "Country"}, inplace=True)

# %%
covid.head()
# Out:
#   State      Country       Lat       Long        Date  Confirmed  Deaths  \
# 0   NaN  Afghanistan  33.93911  67.709953  2020-01-22          0       0
# 1   NaN      Albania  41.15330  20.168300  2020-01-22          0       0
# 2   NaN      Algeria  28.03390   1.659600  2020-01-22          0       0
# 3   NaN      Andorra  42.50630   1.521800  2020-01-22          0       0
# 4   NaN       Angola -11.20270  17.873900  2020-01-22          0       0
#
#    Recovered  Active             WHO Region
# 0          0       0  Eastern Mediterranean
# 1          0       0                 Europe
# 2          0       0                 Africa
# 3          0       0                 Europe
# 4          0       0                 Africa

# %%
covid["State"].fillna("Unknown", inplace=True)

# %%
covid.isna().sum()
# Out:
# State         0
# Country       0
# Lat           0
# Long          0
# Date          0
# Confirmed     0
# Deaths        0
# Recovered     0
# Active        0
# WHO Region    0
# dtype: int64

# %%
world.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# 1            8318.0           13716.0          464.0  13206188.0
# 2            8944.0            1466.0           30.0  22149351.0
# 3            2300.0            5974.0          100.0  29716907.0
# 4             539.0            9063.0          162.0   3149807.0
#
#    Tests/1M pop      WHO Region
# 0      190640.0        Americas
# 1       62085.0        Americas
# 2       16035.0  South-EastAsia
# 3      203623.0          Europe
# 4       53044.0          Africa

# %%
world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
#  15  WHO Region        184 non-null    object
# dtypes: float64(12), int64(1), object(3)
# memory usage: 26.2+ KB

# %%
world.rename(columns={"Country/Region": "Country", "Serious,Critical": "Serious"}, inplace=True)

# %%
world.head()
# Out:
#         Country      Continent    Population  TotalCases  NewCases  \
# 0           USA  North America  3.311981e+08     5032179       NaN
# 1        Brazil  South America  2.127107e+08     2917562       NaN
# 2         India           Asia  1.381345e+09     2025409       NaN
# 3        Russia         Europe  1.459409e+08      871894       NaN
# 4  South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0  18296.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0   8318.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0   8944.0
# 3      14606.0        NaN        676357.0           NaN     180931.0   2300.0
# 4       9604.0        NaN        387316.0           NaN     141264.0    539.0
#
#    Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop      WHO Region
# 0           15194.0          492.0  63139605.0      190640.0        Americas
# 1           13716.0          464.0  13206188.0       62085.0        Americas
# 2            1466.0           30.0  22149351.0       16035.0  South-EastAsia
# 3            5974.0          100.0  29716907.0      203623.0          Europe
# 4            9063.0          162.0   3149807.0       53044.0          Africa

# %%
world.isna().sum()
# Out:
# Country               0
# Continent             1
# Population            1
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious              87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
world["Continent"].fillna("Asia", inplace=True)

# %%
world.isna().sum()
# Out:
# Country               0
# Continent             0
# Population            1
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious              87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
num = int(world["Population"].mean())
world.Population.fillna(num, inplace=True)

# %%
world["Population"].astype(int)
# Out:
# 0       331198130
# 1       212710692
# 2      1381344997
# 3       145940924
# 4        59381566
#           ...
# 204          4992
# 205         26247
# 206          3489
# 207           801
# 208        598682
# Name: Population, Length: 209, dtype: int32

# %%
world.isna().sum()
# Out:
# Country               0
# Continent             0
# Population            0
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious              87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
world["NewCases"].value_counts(), world.shape
# Out:
# (6590.0    1
#  20.0      1
#  30.0      1
#  1282.0    1
#  Name: NewCases, dtype: int64,
#  (209, 16))

# %%
world["NewCases"].fillna(0, inplace=True)
world["NewCases"].astype(int)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 204    0
# 205    0
# 206    0
# 207    0
# 208    0
# Name: NewCases, Length: 209, dtype: int32

# %%
world.isna().sum()
# Out:
# Country               0
# Continent             0
# Population            0
# TotalCases            0
# NewCases              0
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious              87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
world.head()
# Out:
#         Country      Continent    Population  TotalCases  NewCases  \
# 0           USA  North America  3.311981e+08     5032179       0.0
# 1        Brazil  South America  2.127107e+08     2917562       0.0
# 2         India           Asia  1.381345e+09     2025409       0.0
# 3        Russia         Europe  1.459409e+08      871894       0.0
# 4  South Africa         Africa  5.938157e+07      538184       0.0
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0  18296.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0   8318.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0   8944.0
# 3      14606.0        NaN        676357.0           NaN     180931.0   2300.0
# 4       9604.0        NaN        387316.0           NaN     141264.0    539.0
#
#    Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop      WHO Region
# 0           15194.0          492.0  63139605.0      190640.0        Americas
# 1           13716.0          464.0  13206188.0       62085.0        Americas
# 2            1466.0           30.0  22149351.0       16035.0  South-EastAsia
# 3            5974.0          100.0  29716907.0      203623.0          Europe
# 4            9063.0          162.0   3149807.0       53044.0          Africa

# %%
world["TotalDeaths"].fillna(0, inplace=True)

# %%
world.isna().sum()
# Out:
# Country               0
# Continent             0
# Population            0
# TotalCases            0
# NewCases              0
# TotalDeaths           0
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious              87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# dtype: int64

# %%
world["NewDeaths"].fillna(0, inplace=True)
world["NewRecovered"].fillna(0, inplace=True)
world["TotalRecovered"].fillna(0, inplace=True)

# %%
world.isna().sum()
# Out:
# Country              0
# Continent            0
# Population           0
# TotalCases           0
# NewCases             0
# TotalDeaths          0
# NewDeaths            0
# TotalRecovered       0
# NewRecovered         0
# ActiveCases          4
# Serious             87
# Tot Cases/1M pop     1
# Deaths/1M pop       22
# TotalTests          18
# Tests/1M pop        18
# WHO Region          25
# dtype: int64

# %%
world["ActiveCases"].fillna(0, inplace=True)

# %%
world.rename(columns={"Country/Region": "Country", "Serious,Critical": "Serious"}, inplace=True)

# %%
world.isna().sum()
# Out:
# Country              0
# Continent            0
# Population           0
# TotalCases           0
# NewCases             0
# TotalDeaths          0
# NewDeaths            0
# TotalRecovered       0
# NewRecovered         0
# ActiveCases          0
# Serious             87
# Tot Cases/1M pop     1
# Deaths/1M pop       22
# TotalTests          18
# Tests/1M pop        18
# WHO Region          25
# dtype: int64

# %%
world.loc[world.ActiveCases==0,'Serious'] = world.loc[world.ActiveCases==0,'Serious'].fillna(0)

# %%
world.loc[world.ActiveCases==0,'Serious']
# Out:
# 9      617.0
# 11      73.0
# 29      38.0
# 40      37.0
# 157      0.0
# 166      0.0
# 167      0.0
# 176      0.0
# 181      0.0
# 193      0.0
# 199      0.0
# 201      0.0
# 203      0.0
# 206      0.0
# 207      0.0
# Name: Serious, dtype: float64

# %%
serious = np.mean((world["ActiveCases"])*0.008)
serious
# Out:
# 217.07892822966514

# %%
world["Serious"].fillna(serious, inplace=True)

# %%
world.isna().sum()
# Out:
# Country              0
# Continent            0
# Population           0
# TotalCases           0
# NewCases             0
# TotalDeaths          0
# NewDeaths            0
# TotalRecovered       0
# NewRecovered         0
# ActiveCases          0
# Serious              0
# Tot Cases/1M pop     1
# Deaths/1M pop       22
# TotalTests          18
# Tests/1M pop        18
# WHO Region          25
# dtype: int64

# %%
world.head()
# Out:
#         Country      Continent    Population  TotalCases  NewCases  \
# 0           USA  North America  3.311981e+08     5032179       0.0
# 1        Brazil  South America  2.127107e+08     2917562       0.0
# 2         India           Asia  1.381345e+09     2025409       0.0
# 3        Russia         Europe  1.459409e+08      871894       0.0
# 4  South Africa         Africa  5.938157e+07      538184       0.0
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious  \
# 0     162804.0        0.0       2576668.0           0.0    2292707.0  18296.0
# 1      98644.0        0.0       2047660.0           0.0     771258.0   8318.0
# 2      41638.0        0.0       1377384.0           0.0     606387.0   8944.0
# 3      14606.0        0.0        676357.0           0.0     180931.0   2300.0
# 4       9604.0        0.0        387316.0           0.0     141264.0    539.0
#
#    Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop      WHO Region
# 0           15194.0          492.0  63139605.0      190640.0        Americas
# 1           13716.0          464.0  13206188.0       62085.0        Americas
# 2            1466.0           30.0  22149351.0       16035.0  South-EastAsia
# 3            5974.0          100.0  29716907.0      203623.0          Europe
# 4            9063.0          162.0   3149807.0       53044.0          Africa

# %%
# If we have 0 in Total Cases we can simply use 0 to fill the Total Cases/1M pop, that makes sense
world[world["TotalCases"] == 0]["Tot Cases/1M pop"]
# Out:
# Series([], Name: Tot Cases/1M pop, dtype: float64)

# %% [markdown]
# We got a empty dataframe,so we need to fill this in other way

# %%
world["Tot Cases/1M pop"].fillna("None", inplace=True)

# %%
index = world[world["Tot Cases/1M pop"] == "None"].index
total_pop = int(world["Population"][index])
total_cases = int(world["TotalCases"][index]) + int(world["NewCases"][index])
total_pop, total_cases
# Out:
# (30415486, 712)

# %%
tot_cases_per_1M_pop = (total_cases)/((total_pop)//1000000) 
world.loc[(world["Tot Cases/1M pop"] == "None"), "Tot Cases/1M pop"] = tot_cases_per_1M_pop

# %%
world.isna().sum()
# Out:
# Country              0
# Continent            0
# Population           0
# TotalCases           0
# NewCases             0
# TotalDeaths          0
# NewDeaths            0
# TotalRecovered       0
# NewRecovered         0
# ActiveCases          0
# Serious              0
# Tot Cases/1M pop     0
# Deaths/1M pop       22
# TotalTests          18
# Tests/1M pop        18
# WHO Region          25
# dtype: int64

# %%
world.loc[world.TotalDeaths==0,'Deaths/1M pop'] = world.loc[world.TotalDeaths==0,'Deaths/1M pop'].fillna(0)

# %%
world.isna().sum()
# Out:
# Country              0
# Continent            0
# Population           0
# TotalCases           0
# NewCases             0
# TotalDeaths          0
# NewDeaths            0
# TotalRecovered       0
# NewRecovered         0
# ActiveCases          0
# Serious              0
# Tot Cases/1M pop     0
# Deaths/1M pop        1
# TotalTests          18
# Tests/1M pop        18
# WHO Region          25
# dtype: int64

# %%
world["Deaths/1M pop"].fillna("None", inplace=True)

# %%
index = world[world["Deaths/1M pop"] == "None"].index
total_pop = int(world["Population"][index])
total_deaths = int(world["TotalDeaths"][index]) + int(world["NewDeaths"][index])
total_pop, total_deaths
# Out:
# (30415486, 13)

# %%
tot_deaths_per_1M_pop = (total_deaths)/((total_pop)//1000000) 
world.loc[(world["Deaths/1M pop"] == "None"), "Deaths/1M pop"] = tot_deaths_per_1M_pop

# %%
world.isna().sum()
# Out:
# Country              0
# Continent            0
# Population           0
# TotalCases           0
# NewCases             0
# TotalDeaths          0
# NewDeaths            0
# TotalRecovered       0
# NewRecovered         0
# ActiveCases          0
# Serious              0
# Tot Cases/1M pop     0
# Deaths/1M pop        0
# TotalTests          18
# Tests/1M pop        18
# WHO Region          25
# dtype: int64

# %%
world.head()
# Out:
#         Country      Continent    Population  TotalCases  NewCases  \
# 0           USA  North America  3.311981e+08     5032179       0.0
# 1        Brazil  South America  2.127107e+08     2917562       0.0
# 2         India           Asia  1.381345e+09     2025409       0.0
# 3        Russia         Europe  1.459409e+08      871894       0.0
# 4  South Africa         Africa  5.938157e+07      538184       0.0
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious  \
# 0     162804.0        0.0       2576668.0           0.0    2292707.0  18296.0
# 1      98644.0        0.0       2047660.0           0.0     771258.0   8318.0
# 2      41638.0        0.0       1377384.0           0.0     606387.0   8944.0
# 3      14606.0        0.0        676357.0           0.0     180931.0   2300.0
# 4       9604.0        0.0        387316.0           0.0     141264.0    539.0
#
#   Tot Cases/1M pop Deaths/1M pop  TotalTests  Tests/1M pop      WHO Region
# 0          15194.0         492.0  63139605.0      190640.0        Americas
# 1          13716.0         464.0  13206188.0       62085.0        Americas
# 2           1466.0          30.0  22149351.0       16035.0  South-EastAsia
# 3           5974.0         100.0  29716907.0      203623.0          Europe
# 4           9063.0         162.0   3149807.0       53044.0          Africa

# %%
world["TotalTests"].fillna("None", inplace=True)

# %%
world.index[world["TotalTests"] == "None"].tolist()
# Out:
# [54,
#  82,
#  86,
#  106,
#  108,
#  111,
#  130,
#  138,
#  142,
#  145,
#  149,
#  156,
#  161,
#  163,
#  169,
#  184,
#  207,
#  208]

# %%
column = world["TotalTests"]
for idx in world.index[world["TotalTests"] == "None"].tolist():
    if column[idx] == "None":
        column[idx] = (world["TotalCases"][idx]) + (world["NewCases"][idx]) + (world["TotalDeaths"][idx])+(world["NewDeaths"][idx])+(world["TotalRecovered"][idx])+(world["NewRecovered"][idx])

# %%
world[106:112]
# Out:
#         Country      Continent  Population  TotalCases  NewCases  TotalDeaths  \
# 106   Nicaragua  North America   6632263.0        3902       0.0        123.0
# 107   Hong Kong           Asia   7503041.0        3850       0.0         46.0
# 108       Congo         Africa   5530506.0        3546       0.0         58.0
# 109  Montenegro         Europe    628074.0        3480       0.0         60.0
# 110    Thailand           Asia  69817894.0        3330       0.0         58.0
# 111     Somalia         Africa  15933012.0        3227       0.0         93.0
#
#      NewDeaths  TotalRecovered  NewRecovered  ActiveCases     Serious  \
# 106        0.0          2913.0           0.0        866.0  217.078928
# 107        0.0          2458.0           0.0       1346.0   39.000000
# 108        0.0          1589.0           0.0       1899.0  217.078928
# 109        0.0          2178.0           0.0       1242.0  217.078928
# 110        0.0          3148.0           0.0        124.0    1.000000
# 111        0.0          1728.0           0.0       1406.0    2.000000
#
#     Tot Cases/1M pop Deaths/1M pop TotalTests  Tests/1M pop  \
# 106            588.0          19.0     6938.0           NaN
# 107            513.0           6.0   692430.0       92287.0
# 108            641.0          10.0     5193.0           NaN
# 109           5541.0          96.0    38427.0       61182.0
# 110             48.0           0.8   749213.0       10731.0
# 111            203.0           6.0     5048.0           NaN
#
#                WHO Region
# 106              Americas
# 107        WesternPacific
# 108                Africa
# 109                Europe
# 110        South-EastAsia
# 111  EasternMediterranean

# %%
world.isna().sum()
# Out:
# Country              0
# Continent            0
# Population           0
# TotalCases           0
# NewCases             0
# TotalDeaths          0
# NewDeaths            0
# TotalRecovered       0
# NewRecovered         0
# ActiveCases          0
# Serious              0
# Tot Cases/1M pop     0
# Deaths/1M pop        0
# TotalTests           0
# Tests/1M pop        18
# WHO Region          25
# dtype: int64

# %%
world["Tests/1M pop"].fillna("None", inplace=True)

# %%
column = world["Tests/1M pop"]
for idx in world.index[world["Tests/1M pop"] == "None"].tolist():
    if column[idx] == "None":
        total_pop = (world["Population"][idx])*10000
        total_tests = world["TotalTests"][idx]
        tot_test_per_1M_pop = (total_tests)/((total_pop)//1000000) 
        column[idx] = tot_test_per_1M_pop / 10000

# %%
world[106:112]
# Out:
#         Country      Continent  Population  TotalCases  NewCases  TotalDeaths  \
# 106   Nicaragua  North America   6632263.0        3902       0.0        123.0
# 107   Hong Kong           Asia   7503041.0        3850       0.0         46.0
# 108       Congo         Africa   5530506.0        3546       0.0         58.0
# 109  Montenegro         Europe    628074.0        3480       0.0         60.0
# 110    Thailand           Asia  69817894.0        3330       0.0         58.0
# 111     Somalia         Africa  15933012.0        3227       0.0         93.0
#
#      NewDeaths  TotalRecovered  NewRecovered  ActiveCases     Serious  \
# 106        0.0          2913.0           0.0        866.0  217.078928
# 107        0.0          2458.0           0.0       1346.0   39.000000
# 108        0.0          1589.0           0.0       1899.0  217.078928
# 109        0.0          2178.0           0.0       1242.0  217.078928
# 110        0.0          3148.0           0.0        124.0    1.000000
# 111        0.0          1728.0           0.0       1406.0    2.000000
#
#     Tot Cases/1M pop Deaths/1M pop TotalTests Tests/1M pop  \
# 106            588.0          19.0     6938.0      0.00001
# 107            513.0           6.0   692430.0      92287.0
# 108            641.0          10.0     5193.0     0.000009
# 109           5541.0          96.0    38427.0      61182.0
# 110             48.0           0.8   749213.0      10731.0
# 111            203.0           6.0     5048.0     0.000003
#
#                WHO Region
# 106              Americas
# 107        WesternPacific
# 108                Africa
# 109                Europe
# 110        South-EastAsia
# 111  EasternMediterranean

# %%
world.isna().sum()
# Out:
# Country              0
# Continent            0
# Population           0
# TotalCases           0
# NewCases             0
# TotalDeaths          0
# NewDeaths            0
# TotalRecovered       0
# NewRecovered         0
# ActiveCases          0
# Serious              0
# Tot Cases/1M pop     0
# Deaths/1M pop        0
# TotalTests           0
# Tests/1M pop         0
# WHO Region          25
# dtype: int64

# %%
world["WHO Region"].fillna("None", inplace=True)

# %%
world.isna().sum()
# Out:
# Country             0
# Continent           0
# Population          0
# TotalCases          0
# NewCases            0
# TotalDeaths         0
# NewDeaths           0
# TotalRecovered      0
# NewRecovered        0
# ActiveCases         0
# Serious             0
# Tot Cases/1M pop    0
# Deaths/1M pop       0
# TotalTests          0
# Tests/1M pop        0
# WHO Region          0
# dtype: int64

# %%
world.to_csv("updated-worldometer")
